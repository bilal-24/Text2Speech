# %%
pip install gTTS
# Out:
# ...
#   Using cached gTTS-2.2.2-py3-none-any.whl (25 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
import os

# %%
my_text = "Bilal bugün nereye gidiceksin? Kiminle görüşeceksin? Eve kaçta geliceksin? "
output = gTTS(text = my_text, lang = "tr", slow = False)
output.save("text_Speech_en.mp3")

# %%
from IPython.display import Audio
audio = Audio(filename = "text_Speech_en.mp3")
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
